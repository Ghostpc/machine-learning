# %%
import numpy as np

# %%
a=np.array([[1,2,3,4],[3,4,5,6]])

# %%
a.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2955bfce3442> in <module>
# ----> 1 a.shape()
#
# TypeError: 'tuple' object is not callable

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi

# %%
a=np.array([1,2,3,4])

# %%
b=a**3

# %%
b
a
# Out:
# array([1, 2, 3, 4])

# %%
b
# Out:
# array([ 1,  8, 27, 64])

# %%
plt.plot(a,b)

# %%
plt.plot(a,b,'*')

# %%
x=np.linspace(0,2*pi,1000)

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.00000000e+00,  6.42787610e-01,  9.84807753e-01,  8.66025404e-01,
#         3.42020143e-01, -3.42020143e-01, -8.66025404e-01, -9.84807753e-01,
#        -6.42787610e-01, -2.44929360e-16])

# %%
x
# Out:
# array([0.        , 0.6981317 , 1.3962634 , 2.0943951 , 2.7925268 ,
#        3.4906585 , 4.1887902 , 4.88692191, 5.58505361, 6.28318531])

# %%
plt.plot(x,y)

# %%
z=np.cos(x)

# %%
plt.plot(x,z)
plt.plot(x,y)

# %%
plt.plot(a,x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-71ae75a45bbc> in <module>
# ----> 1 plt.plot(a,x)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (4,) and (10,)

# %%
x
# Out:
# array([ 0.        ,  5.55555556, 11.11111111, 16.66666667, 22.22222222,
#        27.77777778, 33.33333333, 38.88888889, 44.44444444, 50.        ])

# %%
plt.plot(a,b,'g')

# %%
plt.plot(a,b,color='green')

# %%
plt.plot(a,b,color='green',marker="*")

# %%
plt.plot(a,b,'.*')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-44b2c353df03> in <module>
# ----> 1 plt.plot(a,b,'.*')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340         ret = []
#     341         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 342             linestyle, marker, color = _process_plot_format(tup[-1])
#     343             tup = tup[:-1]
#     344         elif len(tup) == 3:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _process_plot_format(fmt)
#     103             if marker is not None:
#     104                 raise ValueError(
# --> 105                     'Illegal format string "%s"; two marker symbols' % fmt)
#     106             marker = c
#     107         elif c in mcolors.get_named_colors_mapping():
#
# ValueError: Illegal format string ".*"; two marker symbols

# %%
plt.xlabel("Angles")
plt.ylabel("sin(x)")
plt.plot(x,z)
plt.plot(x,y)

# %%
plt.plot(x,z,'g',label='sin(x)')
plt.plot(x,y,'b',label='cos(x)')
plt.legend()

# %%
plt.plot(x,y,'r-.',x,z,'g')
# Out:
# [<matplotlib.lines.Line2D at 0x7f9318cc58d0>,
#  <matplotlib.lines.Line2D at 0x7f9318cc5a20>]

# %%
plt.bar(a,b,color='red')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(a,b)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(a,b)

# %%
plt.scatter(x,y)

# %%
t1=np.linspace(0,20,15)

# %%
t2=t1**2

# %%
plt.scatter(t1,t2)
plt.plot(t1,t2)

# %%
a=np.array([50,45,5],dtype=int)

# %%
plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9318a90748>,
#   <matplotlib.patches.Wedge at 0x7f9318a90c18>,
#   <matplotlib.patches.Wedge at 0x7f9318a9a128>],
#  [Text(6.735557395310444e-17, 1.1, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(1.0864571621685486, -0.17207799037838706, '')])

# %%
exp=[0,0.10]

# %%
plt.pie(a,explode=exp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-bc355d8fbebe> in <module>
# ----> 1 plt.pie(a,explode=exp)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2803         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2804         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2805         data is not None else {}))
#    2806
#    2807
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2810             raise ValueError("'label' must be of length 'x'")
#    2811         if len(x) != len(explode):
# -> 2812             raise ValueError("'explode' must be of length 'x'")
#    2813         if colors is None:
#    2814             get_next_color = self._get_patches_for_fill.get_next_color
#
# ValueError: 'explode' must be of length 'x'
